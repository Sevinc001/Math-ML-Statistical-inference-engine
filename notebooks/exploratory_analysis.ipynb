# %% [markdown]
# # Exploratory Analysis & Engine Validation
# This notebook validates the core math and optimization modules built from scratch for the Mathematics for Machine Learning capstone engine.

# %%
import numpy as np
import sys
import os

# Add src directory to path to import our custom modules
sys.path.append(os.path.abspath('../src'))

from statistics import get_stats, degrees_of_freedom
from optimizer import compute_cost, compute_gradient
from linear_algebra import matrix_multiply

# %%
# Quick sanity check on sample statistics
sample_data = np.array([12.5, 14.1, 15.0, 13.2, 16.4])
n, mean_val, std_val = get_stats(sample_data)
print(f"Sample Size: {n}, Mean: {mean_val:.2f}, Std Dev: {std_val:.2f}")

# %%
import matplotlib.pyplot as plt

# Qrafik nümunəsi: Məlumatların paylanması və vizuallaşdırma
plt.figure(figsize=(8, 4))
plt.hist(sample_data, bins=5, color='skyblue', edgecolor='black')
plt.title('Sample Data Distribution for Statistical Inference')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
